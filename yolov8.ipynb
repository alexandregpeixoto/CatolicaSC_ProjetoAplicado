# %% [markdown]
# Import Yolo

# %%
from ultralytics import YOLO

# %%
from ultralytics.utils.downloads import GITHUB_ASSETS_STEMS
GITHUB_ASSETS_STEMS
# Out:
# ['yolov8n',
#  'yolov8n-cls',
#  'yolov8n-seg',
#  'yolov8n-pose',
#  'yolov8n-obb',
#  'yolov8n-oiv7',
#  'yolov8s',
#  'yolov8s-cls',
#  'yolov8s-seg',
#  'yolov8s-pose',
#  'yolov8s-obb',
#  'yolov8s-oiv7',
#  'yolov8m',
#  'yolov8m-cls',
#  'yolov8m-seg',
#  'yolov8m-pose',
#  'yolov8m-obb',
#  'yolov8m-oiv7',
#  'yolov8l',
#  'yolov8l-cls',
#  'yolov8l-seg',
#  'yolov8l-pose',
#  'yolov8l-obb',
#  'yolov8l-oiv7',
#  'yolov8x',
#  'yolov8x-cls',
#  'yolov8x-seg',
#  'yolov8x-pose',
#  'yolov8x-obb',
#  'yolov8x-oiv7',
#  'yolov5nu',
#  'yolov5n6u',
#  'yolov5su',
#  'yolov5s6u',
#  'yolov5mu',
#  'yolov5m6u',
#  'yolov5lu',
#  'yolov5l6u',
#  'yolov5xu',
#  'yolov5x6u',
#  'yolov3u',
#  'yolov3-sppu',
#  'yolov3-tinyu',
#  'yolov8s-world',
#  'yolov8m-world',
#  'yolov8l-world',
#  'yolov8x-world',
#  'yolov8s-worldv2',
#  'yolov8m-worldv2',
#  'yolov8l-worldv2',
#  'yolov8x-worldv2',
#  'yolov9t',
#  'yolov9s',
#  'yolov9m',
#  'yolov9c',
#  'yolov9e',
#  'yolov10n',
# ...

# %%
from ultralytics import YOLO, settings
settings
# Out:
# {'settings_version': '0.0.5',
#  'datasets_dir': 'D:\\Design\\Google Drive\\Pessoal\\Educação\\Católica de Santa Catarina - Pós-Graduação\\10 - Projeto Aplicado em IA\\Project\\CatolicaSC_ProjetoAplicado\\datasets',
#  'weights_dir': 'weights',
#  'runs_dir': 'D:\\Design\\Google Drive\\Pessoal\\Educação\\Católica de Santa Catarina - Pós-Graduação\x08 - Projeto Aplicado em IA\\Project\\CatolicaSC_ProjetoAplicado\runs',
#  'uuid': '9ddfaff123b0cb23afb06c079bb0545dde6c020fe170914861a76fa65b52282a',
#  'sync': True,
#  'api_key': '',
#  'openai_api_key': '',
#  'clearml': True,
#  'comet': True,
#  'dvc': True,
#  'hub': True,
#  'mlflow': True,
#  'neptune': True,
#  'raytune': True,
#  'tensorboard': True,
#  'wandb': True,
#  'vscode_msg': True}

# %%
settings.update({'runs_dir': 'D:\Design\Google Drive\Pessoal\Educação\Católica de Santa Catarina - Pós-Graduação\10 - Projeto Aplicado em IA\Project\CatolicaSC_ProjetoAplicado\runs'})

# %%
settings
# Out:
# {'settings_version': '0.0.5',
#  'datasets_dir': 'D:\\Design\\Google Drive\\Pessoal\\Educação\\Católica de Santa Catarina - Pós-Graduação\\10 - Projeto Aplicado em IA\\Project\\CatolicaSC_ProjetoAplicado\\datasets',
#  'weights_dir': 'weights',
#  'runs_dir': 'D:\\Design\\Google Drive\\Pessoal\\Educação\\Católica de Santa Catarina - Pós-Graduação\x08 - Projeto Aplicado em IA\\Project\\CatolicaSC_ProjetoAplicado\runs',
#  'uuid': '9ddfaff123b0cb23afb06c079bb0545dde6c020fe170914861a76fa65b52282a',
#  'sync': True,
#  'api_key': '',
#  'openai_api_key': '',
#  'clearml': True,
#  'comet': True,
#  'dvc': True,
#  'hub': True,
#  'mlflow': True,
#  'neptune': True,
#  'raytune': True,
#  'tensorboard': True,
#  'wandb': True,
#  'vscode_msg': True}

# %% [markdown]
# Training

# %%
model = YOLO('yolov8n')  # yolov8n_custom.yaml

# %%
model.train(data='custom_dataset.yaml',
            epochs=30,
            patience=8,
            batch=5,
            imgsz=640,
            workers=8,
            pretrained=True,
            resume=False,
            single_cls=True,
            box=7.5,
            cls=0.5,
            dfl=1.5,
            val=True,
            degrees=0.3,
            hsv_s=0.3,
            hsv_v=0.3,
            scale=0.5,
            fliplr=0.5,
            project=r'D:\\Design\\Google Drive\\Pessoal\\Educação\\Católica de Santa Catarina - Pós-Graduação\\10 - Projeto Aplicado em IA\\Project\\CatolicaSC_ProjetoAplicado\\runs\\detect'
            )
# Out:
# New https://pypi.org/project/ultralytics/8.2.103 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.90  Python-3.10.9 torch-2.1.2+cu118 CUDA:0 (NVIDIA GeForce RTX 3070, 8191MiB)
# ...

# %% [markdown]
# Validation

# %%
model = YOLO('runs/detect/Train (140 Images) - Validation (35 Images)/weights/best.pt')

# %%
results = model.val(project='runs/detect',
                    imgsz=640,
                    batch=16,
                    conf=0.001,
                    iou=0.7,  # Non-Maximum Supression (NMS)
                    save_json=False,  # Save to JSON {image_id, cls, bbox, conf} of each image in dataset
                    save_hybrid=False,  # Bounding box labels + inference on the output image (Ultralytics 8.0.178 = results are wrong when this argmunent is True)
                    split='test')  # train, val or test
# Out:
# Ultralytics YOLOv8.2.90  Python-3.10.9 torch-2.1.2+cu118 CUDA:0 (NVIDIA GeForce RTX 3070, 8191MiB)
# Model summary (fused): 168 layers, 3,006,233 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning D:\Design\Google Drive\Pessoal\Educação\Católica de Santa Catarina - Pós-Graduação\10 - Projeto Aplicado em IA\Project\CatolicaSC_ProjetoAplicado\data\test\labels.cache... 0 images, 9 backgrounds, 0 corrupt: 100%|██████████| 9/9 [00:00<?, ?it/s]
# WARNING  No labels found in D:\Design\Google Drive\Pessoal\Educao\Catlica de Santa Catarina - Ps-Graduao\10 - Projeto Aplicado em IA\Project\CatolicaSC_ProjetoAplicado\data\test\labels.cache, training may not work correctly. See https://docs.ultralytics.com/datasets for dataset formatting guidance.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:15<00:00, 15.55s/it]
#                    all          9          0          0          0          0          0
# ...

# %%
results
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python310\site-packages\IPython\core\formatters.py:708, in PlainTextFormatter.__call__(self, obj)
#     701 stream = StringIO()
#     702 printer = pretty.RepresentationPrinter(stream, self.verbose,
#     703     self.max_width, self.newline,
#     704     max_seq_length=self.max_seq_length,
#     705     singleton_pprinters=self.singleton_printers,
#     706     type_pprinters=self.type_printers,
#     707     deferred_pprinters=self.deferred_printers)
# --> 708 printer.pretty(obj)
#     709 printer.flush()
#     710 return stream.getvalue()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\IPython\lib\pretty.py:410, in RepresentationPrinter.pretty(self, obj)
#     407                         return meth(obj, self, cycle)
#     408                 if cls is not object \
# ...

# %% [markdown]
# Testing

# %%
from ultralytics import YOLO
import cv2

# Load YOLOv8 model
model = YOLO('D:/Design/Google Drive/Pessoal/Educação/Católica de Santa Catarina - Pós-Graduação/10 - Projeto Aplicado em IA/Project/CatolicaSC_ProjetoAplicado/runs/detect/Train (140 Images) - Validation (35 Images)/weights/best.pt')

# Load video
video_path = 'D:/Design/Google Drive/Pessoal/Educação/Católica de Santa Catarina - Pós-Graduação/10 - Projeto Aplicado em IA/Project/CatolicaSC_ProjetoAplicado/data/test/video02.mp4'
cap = cv2.VideoCapture(video_path)

# Check if video opened successfully
if not cap.isOpened():
    print(f"Error: Could not open video {video_path}")
    exit()

ret = True

# Read frames
while ret:
    ret, frame = cap.read()

    if ret:
        # Detect and track objects
        results = model.track(frame, persist=True)

        # Plot results
        frame_ = results[0].plot()

        # Visualize
        cv2.imshow('Object Detection & Tracking', frame_)
        if cv2.waitKey(25) & 0xFF == ord('q'):
            break

# Release the video capture object and close OpenCV windows
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 2 OlympicWeightliftingBumperPlates, 1 Person, 23.0ms
# Speed: 3.0ms preprocess, 23.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 OlympicWeightliftingBumperPlates, 1 Person, 25.0ms
# Speed: 6.0ms preprocess, 25.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 OlympicWeightliftingBumperPlates, 1 Person, 23.0ms
# Speed: 3.0ms preprocess, 23.0ms inference, 10.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 OlympicWeightliftingBumperPlates, 1 Person, 25.0ms
# Speed: 3.0ms preprocess, 25.0ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 OlympicWeightliftingBumperPlates, 1 Person, 12.0ms
# Speed: 4.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 OlympicWeightliftingBumperPlates, 1 Person, 14.0ms
# ...

# %%
from ultralytics import YOLO
import cv2

# Load YOLOv8 pose model
model = YOLO('yolov8n-pose.pt')  # Use a model trained for pose estimation

# Load video
video_path = 'D:/Design/Google Drive/Pessoal/Educação/Católica de Santa Catarina - Pós-Graduação/10 - Projeto Aplicado em IA/Project/CatolicaSC_ProjetoAplicado/data/test/video02.mp4'
cap = cv2.VideoCapture(video_path)

# Check if video opened successfully
if not cap.isOpened():
    print(f"Error: Could not open video {video_path}")
    exit()

ret = True

# Read frames
while ret:
    ret, frame = cap.read()

    if ret:
        # Detect pose keypoints
        results = model(frame)  # Run the pose model on the frame

        # Plot results (includes keypoints like head, shoulders, knees, etc.)
        frame_ = results[0].plot()

        # Visualize
        cv2.imshow('Pose Estimation', frame_)
        if cv2.waitKey(25) & 0xFF == ord('q'):
            break

# Release the video capture object and close OpenCV windows
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 1 person, 53.0ms
# Speed: 2.0ms preprocess, 53.0ms inference, 63.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 31.0ms
# Speed: 3.0ms preprocess, 31.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 32.0ms
# Speed: 6.0ms preprocess, 32.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 31.0ms
# Speed: 3.0ms preprocess, 31.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 19.0ms
# Speed: 2.0ms preprocess, 19.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 22.0ms
# Speed: 2.0ms preprocess, 22.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 15.0ms
# ...

# %%
from ultralytics import YOLO
import cv2

# Load YOLOv8 pose model
pose_model = YOLO('yolov8n-pose.pt')  # Use a model trained for pose estimation
# Load YOLOv8 custom model
custom_model = YOLO('D:/Design/Google Drive/Pessoal/Educação/Católica de Santa Catarina - Pós-Graduação/10 - Projeto Aplicado em IA/Project/CatolicaSC_ProjetoAplicado/runs/detect/Train (140 Images) - Validation (35 Images)/weights/best.pt')

# Load video
video_path = 'D:/Design/Google Drive/Pessoal/Educação/Católica de Santa Catarina - Pós-Graduação/10 - Projeto Aplicado em IA/Project/CatolicaSC_ProjetoAplicado/data/test/video02.mp4'
cap = cv2.VideoCapture(video_path)

# Check if video opened successfully
if not cap.isOpened():
    print(f"Error: Could not open video {video_path}")
    exit()

ret = True

# Read frames
while ret:
    ret, frame = cap.read()

    if ret:
        # Detect pose keypoints
        resultsPoseModel = pose_model(frame)  # Run the pose model on the frame
        # Detect and track objects
        # resultsCustomModel = custom_model.track(frame, persist=True)
        # Detect and track only the "OlympicWeightliftingBumperPlate" class (class index 0)
        resultsCustomModel = custom_model.track(frame, persist=True, classes=[0])  



        # Plot results (includes keypoints like head, shoulders, knees, etc.)
        frame_with_pose = resultsPoseModel[0].plot()
        # Plot results (custom object)
        frame_with_objects = resultsCustomModel[0].plot()

        # Combine results for visualization
        combined_frame = cv2.addWeighted(frame_with_objects, 0.5, frame_with_pose, 0.5, 0)
        
        # Visualize
        cv2.imshow('Pose Estimation', combined_frame)    
        if cv2.waitKey(25) & 0xFF == ord('q'):
            break

# Release the video capture object and close OpenCV windows
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 1 person, 31.0ms
# Speed: 3.0ms preprocess, 31.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 OlympicWeightliftingBumperPlates, 15.0ms
# Speed: 4.0ms preprocess, 15.0ms inference, 16.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 24.0ms
# Speed: 8.0ms preprocess, 24.0ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 OlympicWeightliftingBumperPlates, 19.0ms
# Speed: 3.0ms preprocess, 19.0ms inference, 11.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 28.0ms
# Speed: 3.0ms preprocess, 28.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 OlympicWeightliftingBumperPlates, 20.0ms
# Speed: 2.0ms preprocess, 20.0ms inference, 9.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 17.0ms
# Speed: 3.0ms preprocess, 17.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# ...
